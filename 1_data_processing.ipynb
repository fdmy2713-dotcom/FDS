# %% [markdown]
# ## 1. Handling Missing Data

# %%
import pandas as pd

## use this for local jupyter notebook
## ------------------------------------
# import os
# os.chdir('C:\\Users\\taiho\\Documents\\D_Drive\\Teaching Assignments\\PSB_Academy\\Hertfordshire_Course\\1_Masters_Fundamentals_of_Data_Science\\2_Personal_Materials\\3_Codes\\1_topical_codes\\data')
# df = pd.read_csv('simple_missing_data.csv')

## use this for colab
## -------------------
from google.colab import drive

drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/12_PSB_Academy/2_UH/1_MSc_FDS/SHARED/2_codes/data/simple_missing_data.csv' ## '/content/drive/<GOOGLE DRIVE PATH>'
df = pd.read_csv(file_path)
## --------

print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      name  score
# 0  Andrew   78.0
# 1   Betty   82.0
# 2   Candy    NaN
# 3   David   75.0
# 4   Ellen    NaN
# 5    Gary   60.0

# %%
## option 1: drop rows with missing data
df_dropped_rows = df.dropna()
print(df_dropped_rows)
# Out:
#      name  score
# 0  Andrew   78.0
# 1   Betty   82.0
# 3   David   75.0
# 5    Gary   60.0

# %%
## option 2: impute missing data

## (1) median imputation (you can also use mean)
## --------------------------------------------
df['score'] = df['score'].fillna(df['score'].median())
print(df)
# Out:
#      name  score
# 0  Andrew   78.0
# 1   Betty   82.0
# 2   Candy   76.5
# 3   David   75.0
# 4   Ellen   76.5
# 5    Gary   60.0

# %% [markdown]
# ## 2. Handling Duplicative Data

# %%
df = pd.read_csv('duplicative_data.csv')
print(df)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           5.1          3.5           1.4          0.2  setosa
# 4           4.9          3.0           1.4          0.2  setosa
# 5           4.7          3.2           1.3          0.2  setosa

# %%
df_cleaned = df.drop_duplicates()
print(df_cleaned)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
